# %% [markdown]
# **Question**:What is the difference between data and ndata? What is the purpose of the method detach()?
# You may look for an answer online.
#
# **Answer**
#
# **Data**:is a Pytorch Tensor
#
# **ndata** : It is a NumPy array
# Purpose of detach():
# It removes the tensor  from the computational graph so gradients are not tracked.This allows safe conversion to Numpy

# %% [markdown]
# **What is covariance matrix size?**
#
# Since data has 784 features:
#
# Covariance matrix size = 784 × 784
#
# **What is explained variance?**
#
# Explained variance tells how much information (variance) each principal component captures.
#
# **How obtained?**
#
# • In sklearn → automatically via SVD
# • In manual method → from eigenvalues of covariance matrix
#
# Explained variance ratio =
#
# 𝜆
# 𝑖/
# ∑
# 𝜆

# %% [markdown]
# **Answer** :
#
# Even though both datasets have dimensionality 784, the dataset with 2500 datapoints contains significantly more information about the true data distribution. With only 4 datapoints, the variance is artificially limited and concentrated in very few directions. When using 2500 datapoints, PCA captures a more realistic variance structure of MNIST, so more principal components are required to explain 99% of the variance.
